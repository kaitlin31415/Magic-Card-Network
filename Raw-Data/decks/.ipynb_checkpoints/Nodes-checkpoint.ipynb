# %% [markdown]
# # Nodes Information

# %%
import pandas as pd

# %%
import json
 
# Opening JSON file
with open('card_info.json', encoding="utf-8") as json_file:
    data = json.load(json_file)

# %%
dataFrameHistorical = pd.DataFrame() 
dfItem = pd.DataFrame.from_records(data)               
dataFrameHistorical = dataFrameHistorical.append(dfItem, ignore_index=True)

# %%
 pd.DataFrame.from_dict(data).describe()
# Out:
#                                                     cards
# count                                                4768
# unique                                               4756
# top     {'object': 'card', 'id': 'b5cb6da6-d43b-4ad1-b...
# freq                                                    2

# %%
dataFrameHistorical = pd.DataFrame() 

for item in data['cards']:
    dfItem = pd.DataFrame.from_dict(item, orient='index')
    dfItem = dfItem.transpose()
    dataFrameHistorical = dataFrameHistorical.append(dfItem, ignore_index=True)

# %%
dataFrameHistorical.head()
# Out:
#   object                                    id  \
# 0   card  18092f68-b96e-4084-9eba-b240d2195d81
# 1   card  1865ab25-b01a-4e2c-bf19-ffcb0806358f
# 2   card  9a52c265-6920-4929-ba0a-70da08df01f1
# 3   card  46f17b66-2484-49f4-80db-408bfda95aa9
# 4   card  25ac5405-df7b-4097-914a-022cb18e20d4
#
#                               oracle_id multiverse_ids mtgo_id arena_id  \
# 0  38515f89-348b-4cf3-b7bd-1f6fe4ce2fba       [534751]   92916    78322
# 1  c6a606af-ea08-4cd9-bfd9-60d76e232e85       [539340]   93574      NaN
# 2  7246d45b-2185-4cdd-981b-5419b7d52bce       [426704]   63606      NaN
# 3  0bc7f093-bef0-4f1a-852c-4b75ebf54838       [545779]     NaN      NaN
# 4  c5acf2a5-40f4-433d-a74d-1cb56c521464       [522320]   90869      NaN
#
#   tcgplayer_id cardmarket_id                         name lang  ...  \
# 0       248137        574937  Adeline, Resplendent Cathar   en  ...
# 1       248580        575359        Angel of Glory's Rise   en  ...
# 2       130149        296825          Anointed Procession   en  ...
# 3       254178        584139                Arcane Signet   en  ...
# 4       238607        564641                    Arid Mesa   en  ...
#
#       watermark    produced_mana card_faces promo_types tcgplayer_etched_id  \
# 0           NaN              NaN        NaN         NaN                 NaN
# 1           NaN              NaN        NaN         NaN                 NaN
# 2  planeswalker              NaN        NaN         NaN                 NaN
# 3           NaN  [B, G, R, U, W]        NaN         NaN                 NaN
# 4           NaN              NaN        NaN         NaN                 NaN
#
#   loyalty color_indicator printed_name printed_type_line printed_text
# 0     NaN             NaN          NaN               NaN          NaN
# 1     NaN             NaN          NaN               NaN          NaN
# 2     NaN             NaN          NaN               NaN          NaN
# 3     NaN             NaN          NaN               NaN          NaN
# 4     NaN             NaN          NaN               NaN          NaN
#
# [5 rows x 78 columns]

# %%
dataFrameHistorical.to_csv("All_card_info_csv.csv")

# %%
dataFrameHistorical.describe()
# Out:
#        object                                    id  \
# count    4768                                  4768
# unique      1                                  4756
# top      card  609d3ecf-f88d-4268-a8d3-4bf2bcf5df60
# freq     4768                                     2
#
#                                    oracle_id multiverse_ids  mtgo_id  \
# count                                   4768           4768     3707
# unique                                  4756           4729     3695
# top     868e6e68-4367-4073-a864-235d5961ae56             []    83175
# freq                                       2             28        2
#
#         arena_id  tcgplayer_id  cardmarket_id  \
# count        994          4608           4574
# unique       984          4596           4562
# top        73386        221830          12750
# freq           2             2              2
#
#                                    name  lang  ... watermark produced_mana  \
# count                              4768  4768  ...       326           817
# unique                             4756     4  ...        30            42
# top     Malakir Rebirth // Malakir Mire    en  ...       set           [C]
# freq                                  2  4765  ...        60           180
#
#                                                card_faces         promo_types  \
# count                                                 103                  27
# unique                                                 92                   7
# top     [{'object': 'card_face', 'name': 'Bala Ged Rec...  [planeswalkerdeck]
# freq                                                    2                   7
#
#        tcgplayer_etched_id loyalty color_indicator printed_name  \
# count                   23      89               8            3
# unique                  23       7               5            3
# top                 240861       4             [U]        Vigor
# freq                     1      33               2            1
#
#         printed_type_line                                 printed_text
# count                   2                                            2
# unique                  2                                            2
# top          クリーチャー — デビル  先制攻撃\n発生源が対戦相手にダメージを与えるなら、それはその２倍のダメージを与える。
# freq                    1                                            1
#
# [4 rows x 78 columns]

# %% [markdown]
# ## More information

# %%
#Card Database
card_df = pd.read_csv("../cards/cards.csv")
# Out:
# c:\users\kaitlin\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3173: DtypeWarning: Columns (3,13,19,22,43,55,69) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
card_df.head()
# Out:
#    index  id             artist asciiName availability borderColor  \
# 0      0   1       Pete Venters       NaN   mtgo,paper       black
# 1      1   2        Volkan Baǵa       NaN   mtgo,paper       black
# 2      2   3       Justin Sweet       NaN   mtgo,paper       black
# 3      3   4  Matthew D. Wilson       NaN   mtgo,paper       black
# 4      4   5       Rebecca Guay       NaN   mtgo,paper       black
#
#    cardKingdomEtchedId  cardKingdomFoilId  cardKingdomId colorIdentity  ...  \
# 0                  NaN                NaN       122719.0             W  ...
# 1                  NaN                NaN       122720.0             W  ...
# 2                  NaN                NaN       122725.0             W  ...
# 3                  NaN           123094.0       122726.0             W  ...
# 4                  NaN           123095.0       122727.0             W  ...
#
#   supertypes tcgplayerEtchedProductId  tcgplayerProductId  \
# 0        NaN                      NaN             15032.0
# 1        NaN                      NaN             15033.0
# 2        NaN                      NaN             15045.0
# 3        NaN                      NaN             15048.0
# 4        NaN                      NaN             15049.0
#
#                                                 text  toughness  \
# 0  First strike (This creature deals combat damag...          4
# 1  Flying\nWhen Angel of Mercy enters the battlef...          3
# 2  Flying (This creature can't be blocked except ...          2
# 3  {X}{W}, {T}: Ballista Squad deals X damage to ...          2
# 4  Prevent the next 1 damage that would be dealt ...        NaN
#
#                       type     types                                  uuid  \
# 0  Creature — Human Cleric  Creature  5f8287b1-5bb6-5f4c-ad17-316a40d5bb0c
# 1         Creature — Angel  Creature  57aaebc1-850c-503d-9f6e-bb8d00d8bf7c
# 2  Creature — Bird Soldier  Creature  8ac972b5-9f6e-5cc8-91c3-b9a40a98232e
# 3   Creature — Human Rebel  Creature  a69b404f-144a-5317-b10e-7d9dce135b24
# 4                  Instant   Instant  6d268c95-c176-5766-9a46-c14f739aba1c
#
#                              variations watermark
# 0  b7c19924-b4bf-56fc-aa73-f586e940bd42       NaN
# 1  8fd4e2eb-3eb4-50ea-856b-ef638fa47f8a       NaN
# 2  6adaf14d-43e3-521a-adf1-960c808e5b1a       NaN
# 3                                   NaN       NaN
# 4                                   NaN       NaN
#
# [5 rows x 81 columns]

# %%
network_cards = pd.read_csv("All_card_info_csv.csv")

# %%
network_cards.head()
# Out:
#    Unnamed: 0 object                                    id  \
# 0           0   card  18092f68-b96e-4084-9eba-b240d2195d81
# 1           1   card  1865ab25-b01a-4e2c-bf19-ffcb0806358f
# 2           2   card  9a52c265-6920-4929-ba0a-70da08df01f1
# 3           3   card  46f17b66-2484-49f4-80db-408bfda95aa9
# 4           4   card  25ac5405-df7b-4097-914a-022cb18e20d4
#
#                               oracle_id multiverse_ids  mtgo_id  arena_id  \
# 0  38515f89-348b-4cf3-b7bd-1f6fe4ce2fba       [534751]  92916.0   78322.0
# 1  c6a606af-ea08-4cd9-bfd9-60d76e232e85       [539340]  93574.0       NaN
# 2  7246d45b-2185-4cdd-981b-5419b7d52bce       [426704]  63606.0       NaN
# 3  0bc7f093-bef0-4f1a-852c-4b75ebf54838       [545779]      NaN       NaN
# 4  c5acf2a5-40f4-433d-a74d-1cb56c521464       [522320]  90869.0       NaN
#
#    tcgplayer_id  cardmarket_id                         name  ...  \
# 0      248137.0       574937.0  Adeline, Resplendent Cathar  ...
# 1      248580.0       575359.0        Angel of Glory's Rise  ...
# 2      130149.0       296825.0          Anointed Procession  ...
# 3      254178.0       584139.0                Arcane Signet  ...
# 4      238607.0       564641.0                    Arid Mesa  ...
#
#       watermark              produced_mana card_faces promo_types  \
# 0           NaN                        NaN        NaN         NaN
# 1           NaN                        NaN        NaN         NaN
# 2  planeswalker                        NaN        NaN         NaN
# 3           NaN  ['B', 'G', 'R', 'U', 'W']        NaN         NaN
# 4           NaN                        NaN        NaN         NaN
#
#   tcgplayer_etched_id  loyalty color_indicator printed_name printed_type_line  \
# 0                 NaN      NaN             NaN          NaN               NaN
# 1                 NaN      NaN             NaN          NaN               NaN
# 2                 NaN      NaN             NaN          NaN               NaN
# 3                 NaN      NaN             NaN          NaN               NaN
# 4                 NaN      NaN             NaN          NaN               NaN
#
#    printed_text
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#
# [5 rows x 79 columns]

# %%
#Checking which id matches

# %%
network_cards[network_cards['name'] == 'Arcane Signet']
# Out:
#    Unnamed: 0 object                                    id  \
# 3           3   card  46f17b66-2484-49f4-80db-408bfda95aa9
#
#                               oracle_id multiverse_ids  mtgo_id  arena_id  \
# 3  0bc7f093-bef0-4f1a-852c-4b75ebf54838       [545779]      NaN       NaN
#
#    tcgplayer_id  cardmarket_id           name  ... watermark  \
# 3      254178.0       584139.0  Arcane Signet  ...       NaN
#
#                produced_mana card_faces promo_types tcgplayer_etched_id  \
# 3  ['B', 'G', 'R', 'U', 'W']        NaN         NaN                 NaN
#
#    loyalty color_indicator printed_name printed_type_line  printed_text
# 3      NaN             NaN          NaN               NaN           NaN
#
# [1 rows x 79 columns]

# %%
card_df[['name','id', 'cardKingdomEtchedId','cardKingdomFoilId','cardKingdomId','colorIdentity']][card_df['name'] == 'Arcane Signet']
# Out:
#                 name     id  cardKingdomEtchedId  cardKingdomFoilId  \
# 4950   Arcane Signet   4951                  NaN                NaN
# 11406  Arcane Signet  11407                  NaN                NaN
# 11726  Arcane Signet  11727                  NaN                NaN
# 14482  Arcane Signet  14483                  NaN           239475.0
# 14876  Arcane Signet  14877                  NaN           239876.0
# 19426  Arcane Signet  19427                  NaN                NaN
# 26793  Arcane Signet  26794                  NaN                NaN
# 35808  Arcane Signet  35809                  NaN                NaN
# 47290  Arcane Signet  47291                  NaN                NaN
# 53263  Arcane Signet  53264                  NaN           240036.0
# 53453  Arcane Signet  53454                  NaN                NaN
# 62305  Arcane Signet  62306                  NaN                NaN
#
#        cardKingdomId colorIdentity
# 4950        249072.0           NaN
# 11406       232292.0           NaN
# 11726       244978.0           NaN
# 14482       238952.0           NaN
# 14876       238974.0           NaN
# 19426       227469.0           NaN
# 26793       240754.0           NaN
# 35808       251397.0           NaN
# 47290            NaN           NaN
# 53263       240037.0           NaN
# 53453            NaN           NaN
# 62305       237301.0           NaN

# %%
# This information will be good if we need to look at specific things but For a node list best to use the scryfall list
