# %%
import pandas as pd
import os

# %%
files = [f for f in os.listdir('.') if os.path.isfile(f)]
for f in files:
    # do something

# %%
df = pd.read_csv('02-07-20-beauty-and-the-beast.csv')

# %%
df.head()
# Out:
#   Board  Qty                         Name Printing  Foil  Alter  Signed  \
# 0  main    1  Adeline, Resplendent Cathar      MID   NaN    NaN     NaN
# 1  main    1        Angel of Glory's Rise      AVR   NaN    NaN     NaN
# 2  main    1          Anointed Procession      AKH   NaN    NaN     NaN
# 3  main    1                Arcane Signet      C20   NaN    NaN     NaN
# 4  main    1                    Arid Mesa      MM3   NaN    NaN     NaN
#
#    Condition  Language Commander
# 0        NaN       NaN       NaN
# 1        NaN       NaN       NaN
# 2        NaN       NaN       NaN
# 3        NaN       NaN       NaN
# 4        NaN       NaN       NaN

# %%
cards = df[['Name']]

# %%
cards.head()
# Out:
#                           Name
# 0  Adeline, Resplendent Cathar
# 1        Angel of Glory's Rise
# 2          Anointed Procession
# 3                Arcane Signet
# 4                    Arid Mesa

# %%
df_2 = pd.read_csv('02-07-20-monster-mash.csv')

# %%
df_2.head()
# Out:
#    Board  Qty                  Name Printing Foil  Alter  Signed  Condition  \
# 0  maybe    1        Abandon Reason      NaN  NaN    NaN     NaN        NaN
# 1  maybe    1  Aetherflux Reservoir      NaN  NaN    NaN     NaN        NaN
# 2  maybe    1      Alms of the Vein      NaN  NaN    NaN     NaN        NaN
# 3   main    1     Altar of Dementia      NaN  NaN    NaN     NaN        NaN
# 4   main    1       Ancient Craving      NaN  NaN    NaN     NaN        NaN
#
#    Language Commander
# 0       NaN       NaN
# 1       NaN       NaN
# 2       NaN       NaN
# 3       NaN       NaN
# 4       NaN       NaN

# %%
cards_2 = df_2[['Name']]

# %%
cards_2.tail()
# Out:
#                    Name
# 191      Warstorm Surge
# 192   Wayfarer's Bauble
# 193      Whip of Erebos
# 194  Zombie Infestation
# 195             Zombify

# %%
dfs = [cards, cards_2]
total_cards = pd.concat(dfs)

# %%
files = [f for f in os.listdir('.') if os.path.isfile(f)]
for f in files:
    filename = str(f)
    print(filename)
    if (not (filename == "Card Manipulation.ipynb")):
        more_cards = pd.read_csv(filename)
        more_cards = more_cards[['Name']]
        dfs = [total_cards, more_cards]
        total_cards = pd.concat(dfs)
# Out:
# 02-07-20-beauty-and-the-beast.csv
# 02-07-20-monster-mash.csv
# 03-01-17-the-manliest-95-land-edh-deck-youll-ever-see-c.csv
# 05-02-19-yasova-dragonclaw.csv
# 06-02-20-mono-green-enchantress.csv
# 08-12-15-sacrificial-lamb.csv
# 13-12-20-rakdos.csv
# 15-03-19-midsummer-nights-dream.csv
# 17-08-19-atraxa.csv
# 18-04-21-thassa-flicker.csv
# 18-07-17-titania-edh.csv
# 19-02-15-teysa.csv
# 19-02-20-rhyss-pieces.csv
# 2-spooky-2.csv
# 20-02-17-spooders.csv
# 21-01-20-ocean-man.csv
# 22-12-17-zurgo-edh.csv
# 29-07-19-omnath-locus-of-mana.csv
# a-good-day-to-die-1.csv
# accursed-potions-and-twisted-notions.csv
# aguamenti.csv
# alela-all-the-things.csv
# alela-artificial-eggs.csv
# alela-constellation-1.csv
# attack-of-the-hogaak.csv
# backstreet-elves.csv
# bruna-i-swear-i-dont-run-enchantments.csv
# built-from-scratch-upgrade.csv
# Card Manipulation.ipynb
# cerberus-the-guard-dog-of-hades.csv
# cheapskate-competitive-talrand-budget-100.csv
# ...

# %%
total_cards.describe()
# Out:
#             Name
# count      22373
# unique      4768
# top     Sol Ring
# freq         181

# %%
total_cards.describe()
# Out:
#             Name
# count       6523
# unique      2946
# top     Sol Ring
# freq          54

# %%
unique_cards = total_cards['Name'].unique()

# %%
unique_cards
# Out:
# array(['Adeline, Resplendent Cathar', "Angel of Glory's Rise",
#        'Anointed Procession', ..., 'Ring of Three Wishes',
#        'Sun Quan, Lord of Wu', "Tyrant's Familiar"], dtype=object)

# %%
# !pip install requests

# %%
import requests
import csv
from time import sleep


url = "https://api.scryfall.com/cards/named?exact=CARDNAME"

payload={}
headers = {}
f1 = open('card_info.csv', 'w', encoding="utf-8")
writer1 = csv.writer(f1)

for card in unique_cards:
    response = requests.request("GET", url.replace("CARDNAME", card), headers=headers, data=payload)
    f1.write("{cardname},{cardinfo}\n".format(cardname=card, cardinfo=response.text))
    sleep(0.10)

# %%
card_nodes = pd.read_csv("card_info.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1820/1544339663.py in <module>
# ----> 1 card_nodes = pd.read_csv("card_info.csv")
#
# c:\users\kaitlin\appdata\local\programs\python\python37\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
# ...
